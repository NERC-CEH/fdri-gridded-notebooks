# %% [markdown]
# <a href="https://colab.research.google.com/github/kitmacleod/fdri-notebooks/blob/main/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CEH-GEAR hourly, daily and monthly rainfall
# Gridded estimates of hourly (1990-2016), daily, and monthly (1890-2019) rainfall for the United Kingdom. One km gridded estimates derived from the Met Office national database of observed precipitation.
#
# Metadata for [CEH-GEAR Hourly](https://catalogue.ceh.ac.uk/documents/fc9423d6-3d54-467f-bb2b-fc7357a3941f) and [CEH-GEAR Daily and Monthly](https://catalogue.ceh.ac.uk/documents/dbf13dd5-90cd-457a-a986-f2f9dd97e93c).
#
# Dataset licensed [Open Government Licence](https://eidc.ac.uk/licences/ogl/plain)
#
# ## Overview

# %%
# Instructions for running locally and in other locations #todo

# %%
# %%capture
# Installing packages that are required above the ones already installed in Google Colab - ONLY NEEDS TO BE RUN IF USING GOOGLE COLAB
# !pip install zarr cftime s3fs netCDF4==1.6.0

# If you are running this notebook in a platform other than Google Colab, please use the following command to install all the required packages. NOT REQUIRED FOR BINDER
#!python -m pip install -r requirements.txt

# %% [markdown]
# ## Downloading a single NetCDF file

# %%
# !wget https://catalogue.ceh.ac.uk/datastore/eidchub/dbf13dd5-90cd-457a-a986-f2f9dd97e93c/GB/monthly/CEH_GEAR_monthly_GB_1894.nc

# %% [markdown]
# ## Reading a single NetCDF file

# %% [markdown]
# ## Reading a Zarr version

# %%
import xarray as xr
# swap URL for the link

ds = xr.open_zarr("URL", chunks=None)
ds

# %% [markdown]
# ### Plot data (time series)

# %%
#todo

# %% [markdown]
# ### Plot data (spatial)
