# %% [markdown]
# # Working with HadUK-Grid rainfall data
# ## Zarr version using R
#
# <img width="309" height="57" alt="UKCEH and FDRI logos" src="https://github.com/user-attachments/assets/04afdc63-663f-41e4-b29d-9419f78d76c3" />
# </br>
#
# **Authors:** [Matt Dalle Piagge](https://mattjbr123.github.io/) and Kit Macleod. With help from: Matt Fry, Mike Brown, Anna Rose Klaptocz, Faiza Samreen, Matt Coole
#
# ---
#
# **Launch this notebook**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NERC-CEH/fdri-gridded-notebooks/blob/main/notebooks/HadUK-Grid/hadukgrid_zarr_R.ipynb)
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/NERC-CEH/fdri-gridded-notebooks/HEAD?labpath=notebooks/HadUK-Grid/hadukgrid_zarr_R.ipynb)
#
# (Ctrl + Click to open in a new tab)
#
# > **Google Colab:** If running in Google Colab, you will need to switch to an R runtime. Click the "Runtime" menu in the menu bar at the top of the screen, select Change runtime type, select R from the 'Runtime type' drop down box, you can leave the rest the same.
#
# Full instructions available in the [accompanying README](https://github.com/NERC-CEH/fdri-gridded-notebooks/blob/main/README.md#R).
#
# ---
#
# ## About this notebook
#
# This notebook explores **HadUK-Grid Rainfall**. [HadUK-Grid](https://catalogue.ceda.ac.uk/uuid/4dc8450d889a491ebb20e724debe2dfb/) is an observations-derived gridded dataset for the UK produced by the [UK Met Office](https://www.metoffice.gov.uk/research/climate/maps-and-data/data/haduk-grid/haduk-grid). It consists of many meteorological variables at various temporal and spatial resolutions. Here we will explore the daily, 1km rainfall dataset which runs from 1891. We use v1.3.1 of the dataset in this notebook but the dataset is regularly updated by the Met Office and for access to the definitive dataset we recommend using the links above.
#
# Simple examples are shown for exploring and working with the dataset, which can be generalised to any gridded dataset stored on S3 storage, a storage medium that is becoming increasingly common for large gridded datasets. Datasets on S3 storage are typically stored in the Zarr format.
#
# **We will:**
# 1. Show how to open a dataset stored in Zarr format
# 2. Show how to extract and plot a time series at a single location
# 3. Show how to plot a map of rainfall at a single time step
#
# **Data store and chunking**
#
# The data is currently publicly available as a trial through JASMIN object storage at the following URLs:
#
# ```
# https://fdri-o.s3-ext.jc.rl.ac.uk/hadukgrid-rainfall-spacechunk/hadukgrid_rainfall_10km_chunks_all.zarr
# https://fdri-o.s3-ext.jc.rl.ac.uk/hadukgrid-rainfall-timechunk/hadukgrid_rainfall_week_chunks_all.zarr
# ```
#
# Each URL links to an identical copy of the dataset, but split up into chunks differently, to enable more performant access for particular types of analysis.
#
# The 'hadukgrid-rainfall-spacechunk' version is chunked across the spatial dimensions and is more performant for access patterns that extract out timeseries from a single gridpoint or small spatial areas.
#
# The 'hadukgrid-rainfall-timechunk' version is chunked across the time dimension and is more performant for access patterns that extract out large spatial areas at a single timestep or small number of timesteps.
#
# ---

# %% [markdown]
# ## 0. Setup
#
# Install and load the `stars` package and associated libraries. This can take several minutes.

# %%
# ── Install packages ──────────────────────────────────────────────────────────
pkgs <- c("stars", "sf", "dplyr", "tidyr", "scales", "lubridate", "ggplot2", "CFtime")
new  <- pkgs[!pkgs %in% installed.packages()[, "Package"]]
if (length(new) > 0) install.packages(new, repos = "https://cloud.r-project.org", verbose = TRUE)

# %%
# ── Load ──────────────────────────────────────────────────────────────────────
suppressPackageStartupMessages({
  library(stars)            # Spatiotemporal arrays / data cubes
  library(sf)               # Spatial features
  library(dplyr)            # Data wrangling
  library(tidyr)
  library(scales)           # Axis formatting
  library(lubridate)        # Date handling
  library(ggplot2)          # Plotting
})

cat("stars version:", as.character(packageVersion("stars")), "\n")
# Out:
# stars version: 0.7.2

# %% [markdown]
# ---
# ## 1. Open the Zarr store
#
# Here, we read in all the dataset metadata using the store URL and gdal's Zarr support. We will read in both versions of the dataset.

# %% [markdown]
# Time-chunked version:

# %%
# ── Store URL ─────────────────────────────────────────────────────────────────
store_url_timechunk <- "https://fdri-o.s3-ext.jc.rl.ac.uk/hadukgrid-rainfall-timechunk/hadukgrid_rainfall_week_chunks_all.zarr"

# Build the GDAL Zarr connection string
# read_mdim() uses GDAL's multidimensional array API, which handles time and
# all coordinate dimensions natively
gdal_url_timechunk <- paste0('ZARR:"/vsicurl/', store_url_timechunk, '"')

info_timechunk <- gdal_utils("mdiminfo", gdal_url_timechunk, quiet = TRUE)
info_json_timechunk <- jsonlite::fromJSON(info_timechunk, simplifyVector = FALSE)

print(info_json_timechunk)
# Out:
# $type
# [1] "group"
#
# $driver
# [1] "Zarr"
#
# $name
# [1] "/"
#
# $attributes
# $attributes$Conventions
# [1] "CF-1.7"
#
# $attributes$comment
# [1] "Daily resolution gridded climate observations"
#
# $attributes$coordinates
# [1] "projection_x_coordinate_bnds projection_y_coordinate_bnds time_bnds transverse_mercator"
#
# $attributes$frequency
# [1] "day"
#
# $attributes$institution
# [1] "Met Office"
#
# $attributes$references
# [1] "doi: 10.1002/gdj3.78"
#
# $attributes$short_name
# [1] "daily_rainfall"
#
# $attributes$source
# [1] "HadUK-Grid_v1.3.1.0"
#
# $attributes$title
# [1] "Gridded surface climate observations data for the UK"
#
# $attributes$version
# [1] "v20250415"
#
#
# $dimensions
# $dimensions[[1]]
# $dimensions[[1]]$name
# [1] "bnds"
#
# $dimensions[[1]]$full_name
# [1] "/bnds"
#
# $dimensions[[1]]$size
# [1] 2
#
#
# $dimensions[[2]]
# $dimensions[[2]]$name
# [1] "projection_x_coordinate"
#
# $dimensions[[2]]$full_name
# [1] "/projection_x_coordinate"
#
# $dimensions[[2]]$size
# [1] 900
#
# $dimensions[[2]]$type
# [1] "HORIZONTAL_X"
#
# $dimensions[[2]]$indexing_variable
# $dimensions[[2]]$indexing_variable$projection_x_coordinate
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$datatype
# [1] "Float64"
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$dimensions
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$dimensions[[1]]
# [1] "/projection_x_coordinate"
#
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$dimension_size
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$dimension_size[[1]]
# [1] 900
#
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$block_size
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$block_size[[1]]
# [1] 900
#
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$attributes
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$attributes$axis
# [1] "X"
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$attributes$bounds
# [1] "projection_x_coordinate_bnds"
#
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$unit
# [1] "m"
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$nodata_value
# [1] "NaN"
#
#
#
#
# $dimensions[[3]]
# $dimensions[[3]]$name
# [1] "projection_y_coordinate"
#
# $dimensions[[3]]$full_name
# [1] "/projection_y_coordinate"
#
# $dimensions[[3]]$size
# [1] 1450
#
# $dimensions[[3]]$type
# [1] "HORIZONTAL_Y"
#
# $dimensions[[3]]$indexing_variable
# $dimensions[[3]]$indexing_variable$projection_y_coordinate
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$datatype
# [1] "Float64"
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$dimensions
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$dimension_size
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$dimension_size[[1]]
# [1] 1450
#
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$block_size
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$block_size[[1]]
# [1] 1450
#
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$attributes
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$attributes$axis
# [1] "Y"
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$attributes$bounds
# [1] "projection_y_coordinate_bnds"
#
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$unit
# [1] "m"
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$nodata_value
# [1] "NaN"
#
#
#
#
# $dimensions[[4]]
# $dimensions[[4]]$name
# [1] "time"
#
# $dimensions[[4]]$full_name
# [1] "/time"
#
# $dimensions[[4]]$size
# [1] 48943
#
# $dimensions[[4]]$type
# [1] "TEMPORAL"
#
# $dimensions[[4]]$indexing_variable
# $dimensions[[4]]$indexing_variable$time
# $dimensions[[4]]$indexing_variable$time$datatype
# [1] "Int64"
#
# $dimensions[[4]]$indexing_variable$time$dimensions
# $dimensions[[4]]$indexing_variable$time$dimensions[[1]]
# [1] "/time"
#
#
# $dimensions[[4]]$indexing_variable$time$dimension_size
# $dimensions[[4]]$indexing_variable$time$dimension_size[[1]]
# [1] 48943
#
#
# $dimensions[[4]]$indexing_variable$time$block_size
# $dimensions[[4]]$indexing_variable$time$block_size[[1]]
# [1] 48943
#
#
# $dimensions[[4]]$indexing_variable$time$attributes
# $dimensions[[4]]$indexing_variable$time$attributes$axis
# [1] "T"
#
# $dimensions[[4]]$indexing_variable$time$attributes$bounds
# [1] "time_bnds"
#
# $dimensions[[4]]$indexing_variable$time$attributes$calendar
# [1] "standard"
#
#
# $dimensions[[4]]$indexing_variable$time$unit
# [1] "hours since 1800-01-01"
#
#
#
#
#
# $arrays
# $arrays$projection_x_coordinate
# $arrays$projection_x_coordinate$datatype
# [1] "Float64"
#
# $arrays$projection_x_coordinate$dimensions
# $arrays$projection_x_coordinate$dimensions[[1]]
# [1] "/projection_x_coordinate"
#
#
# $arrays$projection_x_coordinate$dimension_size
# $arrays$projection_x_coordinate$dimension_size[[1]]
# [1] 900
#
#
# $arrays$projection_x_coordinate$block_size
# $arrays$projection_x_coordinate$block_size[[1]]
# [1] 900
#
#
# $arrays$projection_x_coordinate$attributes
# $arrays$projection_x_coordinate$attributes$axis
# [1] "X"
#
# $arrays$projection_x_coordinate$attributes$bounds
# [1] "projection_x_coordinate_bnds"
#
#
# $arrays$projection_x_coordinate$unit
# [1] "m"
#
# $arrays$projection_x_coordinate$nodata_value
# [1] "NaN"
#
#
# $arrays$projection_y_coordinate
# $arrays$projection_y_coordinate$datatype
# [1] "Float64"
#
# $arrays$projection_y_coordinate$dimensions
# $arrays$projection_y_coordinate$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
#
# $arrays$projection_y_coordinate$dimension_size
# $arrays$projection_y_coordinate$dimension_size[[1]]
# [1] 1450
#
#
# $arrays$projection_y_coordinate$block_size
# $arrays$projection_y_coordinate$block_size[[1]]
# [1] 1450
#
#
# $arrays$projection_y_coordinate$attributes
# $arrays$projection_y_coordinate$attributes$axis
# [1] "Y"
#
# $arrays$projection_y_coordinate$attributes$bounds
# [1] "projection_y_coordinate_bnds"
#
#
# $arrays$projection_y_coordinate$unit
# [1] "m"
#
# $arrays$projection_y_coordinate$nodata_value
# [1] "NaN"
#
#
# $arrays$time
# $arrays$time$datatype
# [1] "Int64"
#
# $arrays$time$dimensions
# $arrays$time$dimensions[[1]]
# [1] "/time"
#
#
# $arrays$time$dimension_size
# $arrays$time$dimension_size[[1]]
# [1] 48943
#
#
# $arrays$time$block_size
# $arrays$time$block_size[[1]]
# [1] 48943
#
#
# $arrays$time$attributes
# $arrays$time$attributes$axis
# [1] "T"
#
# $arrays$time$attributes$bounds
# [1] "time_bnds"
#
# $arrays$time$attributes$calendar
# [1] "standard"
#
#
# $arrays$time$unit
# [1] "hours since 1800-01-01"
#
#
# $arrays$latitude
# $arrays$latitude$datatype
# [1] "Float64"
#
# $arrays$latitude$dimensions
# $arrays$latitude$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
# $arrays$latitude$dimensions[[2]]
# [1] "/projection_x_coordinate"
#
#
# $arrays$latitude$dimension_size
# $arrays$latitude$dimension_size[[1]]
# [1] 1450
#
# $arrays$latitude$dimension_size[[2]]
# [1] 900
#
#
# $arrays$latitude$block_size
# $arrays$latitude$block_size[[1]]
# [1] 1450
#
# $arrays$latitude$block_size[[2]]
# [1] 900
#
#
# $arrays$latitude$attributes
# $arrays$latitude$attributes$standard_name
# [1] "latitude"
#
#
# $arrays$latitude$unit
# [1] "degrees_north"
#
# $arrays$latitude$nodata_value
# [1] "NaN"
#
#
# $arrays$longitude
# $arrays$longitude$datatype
# [1] "Float64"
#
# $arrays$longitude$dimensions
# $arrays$longitude$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
# $arrays$longitude$dimensions[[2]]
# [1] "/projection_x_coordinate"
#
#
# $arrays$longitude$dimension_size
# $arrays$longitude$dimension_size[[1]]
# [1] 1450
#
# $arrays$longitude$dimension_size[[2]]
# [1] 900
#
#
# $arrays$longitude$block_size
# $arrays$longitude$block_size[[1]]
# [1] 1450
#
# $arrays$longitude$block_size[[2]]
# [1] 900
#
#
# $arrays$longitude$attributes
# $arrays$longitude$attributes$standard_name
# [1] "longitude"
#
#
# $arrays$longitude$unit
# [1] "degrees_east"
#
# $arrays$longitude$nodata_value
# [1] "NaN"
#
#
# $arrays$projection_x_coordinate_bnds
# $arrays$projection_x_coordinate_bnds$datatype
# [1] "Float64"
#
# $arrays$projection_x_coordinate_bnds$dimensions
# $arrays$projection_x_coordinate_bnds$dimensions[[1]]
# [1] "/projection_x_coordinate"
#
# $arrays$projection_x_coordinate_bnds$dimensions[[2]]
# [1] "/bnds"
#
#
# $arrays$projection_x_coordinate_bnds$dimension_size
# $arrays$projection_x_coordinate_bnds$dimension_size[[1]]
# [1] 900
#
# $arrays$projection_x_coordinate_bnds$dimension_size[[2]]
# [1] 2
#
#
# $arrays$projection_x_coordinate_bnds$block_size
# $arrays$projection_x_coordinate_bnds$block_size[[1]]
# [1] 900
#
# $arrays$projection_x_coordinate_bnds$block_size[[2]]
# [1] 2
#
#
# $arrays$projection_x_coordinate_bnds$nodata_value
# [1] "NaN"
#
#
# $arrays$projection_y_coordinate_bnds
# $arrays$projection_y_coordinate_bnds$datatype
# [1] "Float64"
#
# $arrays$projection_y_coordinate_bnds$dimensions
# $arrays$projection_y_coordinate_bnds$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
# $arrays$projection_y_coordinate_bnds$dimensions[[2]]
# [1] "/bnds"
#
#
# $arrays$projection_y_coordinate_bnds$dimension_size
# $arrays$projection_y_coordinate_bnds$dimension_size[[1]]
# [1] 1450
#
# $arrays$projection_y_coordinate_bnds$dimension_size[[2]]
# [1] 2
#
#
# $arrays$projection_y_coordinate_bnds$block_size
# $arrays$projection_y_coordinate_bnds$block_size[[1]]
# [1] 1450
#
# $arrays$projection_y_coordinate_bnds$block_size[[2]]
# [1] 2
#
#
# $arrays$projection_y_coordinate_bnds$nodata_value
# [1] "NaN"
#
#
# $arrays$rainfall
# $arrays$rainfall$datatype
# [1] "Float64"
#
# $arrays$rainfall$dimensions
# $arrays$rainfall$dimensions[[1]]
# [1] "/time"
#
# $arrays$rainfall$dimensions[[2]]
# [1] "/projection_y_coordinate"
#
# $arrays$rainfall$dimensions[[3]]
# [1] "/projection_x_coordinate"
#
#
# $arrays$rainfall$dimension_size
# $arrays$rainfall$dimension_size[[1]]
# [1] 48943
#
# $arrays$rainfall$dimension_size[[2]]
# [1] 1450
#
# $arrays$rainfall$dimension_size[[3]]
# [1] 900
#
#
# $arrays$rainfall$block_size
# $arrays$rainfall$block_size[[1]]
# [1] 7
#
# $arrays$rainfall$block_size[[2]]
# [1] 1450
#
# $arrays$rainfall$block_size[[3]]
# [1] 900
#
#
# $arrays$rainfall$attributes
# $arrays$rainfall$attributes$cell_methods
# [1] "time: sum"
#
# $arrays$rainfall$attributes$coordinates
# [1] "latitude longitude"
#
# $arrays$rainfall$attributes$description
# [1] "Total rainfall"
#
# $arrays$rainfall$attributes$grid_mapping
# [1] "transverse_mercator"
#
# $arrays$rainfall$attributes$label_units
# [1] "mm"
#
# $arrays$rainfall$attributes$level
# [1] "NA"
#
# $arrays$rainfall$attributes$long_name
# [1] "Total rainfall"
#
# $arrays$rainfall$attributes$plot_label
# [1] "Total rainfall (mm)"
#
# $arrays$rainfall$attributes$standard_name
# [1] "lwe_thickness_of_precipitation_amount"
#
#
# $arrays$rainfall$unit
# [1] "mm"
#
# $arrays$rainfall$nodata_value
# [1] 1e+20
#
#
# $arrays$time_bnds
# $arrays$time_bnds$datatype
# [1] "Int64"
#
# $arrays$time_bnds$dimensions
# $arrays$time_bnds$dimensions[[1]]
# [1] "/time"
#
# $arrays$time_bnds$dimensions[[2]]
# [1] "/bnds"
#
#
# $arrays$time_bnds$dimension_size
# $arrays$time_bnds$dimension_size[[1]]
# [1] 48943
#
# $arrays$time_bnds$dimension_size[[2]]
# [1] 2
#
#
# $arrays$time_bnds$block_size
# $arrays$time_bnds$block_size[[1]]
# [1] 7
#
# $arrays$time_bnds$block_size[[2]]
# [1] 2
#
#
# $arrays$time_bnds$attributes
# $arrays$time_bnds$attributes$calendar
# [1] "standard"
#
#
# $arrays$time_bnds$unit
# [1] "hours since 1800-01-01 00:00:00"
#
#
# $arrays$transverse_mercator
# $arrays$transverse_mercator$datatype
# [1] "Int32"
#
# $arrays$transverse_mercator$attributes
# $arrays$transverse_mercator$attributes$false_easting
# [1] 400000
#
# $arrays$transverse_mercator$attributes$false_northing
# [1] -100000
#
# $arrays$transverse_mercator$attributes$grid_mapping_name
# [1] "transverse_mercator"
#
# $arrays$transverse_mercator$attributes$latitude_of_projection_origin
# [1] 49
#
# $arrays$transverse_mercator$attributes$longitude_of_central_meridian
# [1] -2
#
# $arrays$transverse_mercator$attributes$longitude_of_prime_meridian
# [1] 0
#
# $arrays$transverse_mercator$attributes$scale_factor_at_central_meridian
# [1] 0.9996013
#
# $arrays$transverse_mercator$attributes$semi_major_axis
# [1] 6377563
#
# $arrays$transverse_mercator$attributes$semi_minor_axis
# [1] 6356257

# %% [markdown]
# Space-chunked version:

# %%
# ── Store URL ─────────────────────────────────────────────────────────────────
store_url_spacechunk <- "https://fdri-o.s3-ext.jc.rl.ac.uk/hadukgrid-rainfall-spacechunk/hadukgrid_rainfall_10km_chunks_all.zarr"

# Build the GDAL Zarr connection string
# read_mdim() uses GDAL's multidimensional array API, which handles time and
# all coordinate dimensions natively
gdal_url_spacechunk <- paste0('ZARR:"/vsicurl/', store_url_spacechunk, '"')

info_spacechunk <- gdal_utils("mdiminfo", gdal_url_spacechunk, quiet = TRUE)
info_json_spacechunk <- jsonlite::fromJSON(info_spacechunk, simplifyVector = FALSE)

print(info_json_spacechunk)
# Out:
# $type
# [1] "group"
#
# $driver
# [1] "Zarr"
#
# $name
# [1] "/"
#
# $attributes
# $attributes$Conventions
# [1] "CF-1.7"
#
# $attributes$comment
# [1] "Daily resolution gridded climate observations"
#
# $attributes$coordinates
# [1] "projection_x_coordinate_bnds projection_y_coordinate_bnds time_bnds transverse_mercator"
#
# $attributes$frequency
# [1] "day"
#
# $attributes$institution
# [1] "Met Office"
#
# $attributes$references
# [1] "doi: 10.1002/gdj3.78"
#
# $attributes$short_name
# [1] "daily_rainfall"
#
# $attributes$source
# [1] "HadUK-Grid_v1.3.1.0"
#
# $attributes$title
# [1] "Gridded surface climate observations data for the UK"
#
# $attributes$version
# [1] "v20250415"
#
#
# $dimensions
# $dimensions[[1]]
# $dimensions[[1]]$name
# [1] "bnds"
#
# $dimensions[[1]]$full_name
# [1] "/bnds"
#
# $dimensions[[1]]$size
# [1] 2
#
#
# $dimensions[[2]]
# $dimensions[[2]]$name
# [1] "projection_x_coordinate"
#
# $dimensions[[2]]$full_name
# [1] "/projection_x_coordinate"
#
# $dimensions[[2]]$size
# [1] 900
#
# $dimensions[[2]]$type
# [1] "HORIZONTAL_X"
#
# $dimensions[[2]]$indexing_variable
# $dimensions[[2]]$indexing_variable$projection_x_coordinate
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$datatype
# [1] "Float64"
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$dimensions
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$dimensions[[1]]
# [1] "/projection_x_coordinate"
#
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$dimension_size
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$dimension_size[[1]]
# [1] 900
#
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$block_size
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$block_size[[1]]
# [1] 900
#
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$attributes
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$attributes$axis
# [1] "X"
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$attributes$bounds
# [1] "projection_x_coordinate_bnds"
#
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$unit
# [1] "m"
#
# $dimensions[[2]]$indexing_variable$projection_x_coordinate$nodata_value
# [1] "NaN"
#
#
#
#
# $dimensions[[3]]
# $dimensions[[3]]$name
# [1] "projection_y_coordinate"
#
# $dimensions[[3]]$full_name
# [1] "/projection_y_coordinate"
#
# $dimensions[[3]]$size
# [1] 1450
#
# $dimensions[[3]]$type
# [1] "HORIZONTAL_Y"
#
# $dimensions[[3]]$indexing_variable
# $dimensions[[3]]$indexing_variable$projection_y_coordinate
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$datatype
# [1] "Float64"
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$dimensions
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$dimension_size
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$dimension_size[[1]]
# [1] 1450
#
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$block_size
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$block_size[[1]]
# [1] 1450
#
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$attributes
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$attributes$axis
# [1] "Y"
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$attributes$bounds
# [1] "projection_y_coordinate_bnds"
#
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$unit
# [1] "m"
#
# $dimensions[[3]]$indexing_variable$projection_y_coordinate$nodata_value
# [1] "NaN"
#
#
#
#
# $dimensions[[4]]
# $dimensions[[4]]$name
# [1] "time"
#
# $dimensions[[4]]$full_name
# [1] "/time"
#
# $dimensions[[4]]$size
# [1] 48943
#
# $dimensions[[4]]$type
# [1] "TEMPORAL"
#
# $dimensions[[4]]$indexing_variable
# $dimensions[[4]]$indexing_variable$time
# $dimensions[[4]]$indexing_variable$time$datatype
# [1] "Int64"
#
# $dimensions[[4]]$indexing_variable$time$dimensions
# $dimensions[[4]]$indexing_variable$time$dimensions[[1]]
# [1] "/time"
#
#
# $dimensions[[4]]$indexing_variable$time$dimension_size
# $dimensions[[4]]$indexing_variable$time$dimension_size[[1]]
# [1] 48943
#
#
# $dimensions[[4]]$indexing_variable$time$block_size
# $dimensions[[4]]$indexing_variable$time$block_size[[1]]
# [1] 48943
#
#
# $dimensions[[4]]$indexing_variable$time$attributes
# $dimensions[[4]]$indexing_variable$time$attributes$axis
# [1] "T"
#
# $dimensions[[4]]$indexing_variable$time$attributes$bounds
# [1] "time_bnds"
#
# $dimensions[[4]]$indexing_variable$time$attributes$calendar
# [1] "standard"
#
#
# $dimensions[[4]]$indexing_variable$time$unit
# [1] "hours since 1800-01-01"
#
#
#
#
#
# $arrays
# $arrays$projection_x_coordinate
# $arrays$projection_x_coordinate$datatype
# [1] "Float64"
#
# $arrays$projection_x_coordinate$dimensions
# $arrays$projection_x_coordinate$dimensions[[1]]
# [1] "/projection_x_coordinate"
#
#
# $arrays$projection_x_coordinate$dimension_size
# $arrays$projection_x_coordinate$dimension_size[[1]]
# [1] 900
#
#
# $arrays$projection_x_coordinate$block_size
# $arrays$projection_x_coordinate$block_size[[1]]
# [1] 900
#
#
# $arrays$projection_x_coordinate$attributes
# $arrays$projection_x_coordinate$attributes$axis
# [1] "X"
#
# $arrays$projection_x_coordinate$attributes$bounds
# [1] "projection_x_coordinate_bnds"
#
#
# $arrays$projection_x_coordinate$unit
# [1] "m"
#
# $arrays$projection_x_coordinate$nodata_value
# [1] "NaN"
#
#
# $arrays$projection_y_coordinate
# $arrays$projection_y_coordinate$datatype
# [1] "Float64"
#
# $arrays$projection_y_coordinate$dimensions
# $arrays$projection_y_coordinate$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
#
# $arrays$projection_y_coordinate$dimension_size
# $arrays$projection_y_coordinate$dimension_size[[1]]
# [1] 1450
#
#
# $arrays$projection_y_coordinate$block_size
# $arrays$projection_y_coordinate$block_size[[1]]
# [1] 1450
#
#
# $arrays$projection_y_coordinate$attributes
# $arrays$projection_y_coordinate$attributes$axis
# [1] "Y"
#
# $arrays$projection_y_coordinate$attributes$bounds
# [1] "projection_y_coordinate_bnds"
#
#
# $arrays$projection_y_coordinate$unit
# [1] "m"
#
# $arrays$projection_y_coordinate$nodata_value
# [1] "NaN"
#
#
# $arrays$time
# $arrays$time$datatype
# [1] "Int64"
#
# $arrays$time$dimensions
# $arrays$time$dimensions[[1]]
# [1] "/time"
#
#
# $arrays$time$dimension_size
# $arrays$time$dimension_size[[1]]
# [1] 48943
#
#
# $arrays$time$block_size
# $arrays$time$block_size[[1]]
# [1] 48943
#
#
# $arrays$time$attributes
# $arrays$time$attributes$axis
# [1] "T"
#
# $arrays$time$attributes$bounds
# [1] "time_bnds"
#
# $arrays$time$attributes$calendar
# [1] "standard"
#
#
# $arrays$time$unit
# [1] "hours since 1800-01-01"
#
#
# $arrays$latitude
# $arrays$latitude$datatype
# [1] "Float64"
#
# $arrays$latitude$dimensions
# $arrays$latitude$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
# $arrays$latitude$dimensions[[2]]
# [1] "/projection_x_coordinate"
#
#
# $arrays$latitude$dimension_size
# $arrays$latitude$dimension_size[[1]]
# [1] 1450
#
# $arrays$latitude$dimension_size[[2]]
# [1] 900
#
#
# $arrays$latitude$block_size
# $arrays$latitude$block_size[[1]]
# [1] 10
#
# $arrays$latitude$block_size[[2]]
# [1] 10
#
#
# $arrays$latitude$attributes
# $arrays$latitude$attributes$standard_name
# [1] "latitude"
#
#
# $arrays$latitude$unit
# [1] "degrees_north"
#
# $arrays$latitude$nodata_value
# [1] "NaN"
#
#
# $arrays$longitude
# $arrays$longitude$datatype
# [1] "Float64"
#
# $arrays$longitude$dimensions
# $arrays$longitude$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
# $arrays$longitude$dimensions[[2]]
# [1] "/projection_x_coordinate"
#
#
# $arrays$longitude$dimension_size
# $arrays$longitude$dimension_size[[1]]
# [1] 1450
#
# $arrays$longitude$dimension_size[[2]]
# [1] 900
#
#
# $arrays$longitude$block_size
# $arrays$longitude$block_size[[1]]
# [1] 10
#
# $arrays$longitude$block_size[[2]]
# [1] 10
#
#
# $arrays$longitude$attributes
# $arrays$longitude$attributes$standard_name
# [1] "longitude"
#
#
# $arrays$longitude$unit
# [1] "degrees_east"
#
# $arrays$longitude$nodata_value
# [1] "NaN"
#
#
# $arrays$projection_x_coordinate_bnds
# $arrays$projection_x_coordinate_bnds$datatype
# [1] "Float64"
#
# $arrays$projection_x_coordinate_bnds$dimensions
# $arrays$projection_x_coordinate_bnds$dimensions[[1]]
# [1] "/projection_x_coordinate"
#
# $arrays$projection_x_coordinate_bnds$dimensions[[2]]
# [1] "/bnds"
#
#
# $arrays$projection_x_coordinate_bnds$dimension_size
# $arrays$projection_x_coordinate_bnds$dimension_size[[1]]
# [1] 900
#
# $arrays$projection_x_coordinate_bnds$dimension_size[[2]]
# [1] 2
#
#
# $arrays$projection_x_coordinate_bnds$block_size
# $arrays$projection_x_coordinate_bnds$block_size[[1]]
# [1] 10
#
# $arrays$projection_x_coordinate_bnds$block_size[[2]]
# [1] 2
#
#
# $arrays$projection_x_coordinate_bnds$nodata_value
# [1] "NaN"
#
#
# $arrays$projection_y_coordinate_bnds
# $arrays$projection_y_coordinate_bnds$datatype
# [1] "Float64"
#
# $arrays$projection_y_coordinate_bnds$dimensions
# $arrays$projection_y_coordinate_bnds$dimensions[[1]]
# [1] "/projection_y_coordinate"
#
# $arrays$projection_y_coordinate_bnds$dimensions[[2]]
# [1] "/bnds"
#
#
# $arrays$projection_y_coordinate_bnds$dimension_size
# $arrays$projection_y_coordinate_bnds$dimension_size[[1]]
# [1] 1450
#
# $arrays$projection_y_coordinate_bnds$dimension_size[[2]]
# [1] 2
#
#
# $arrays$projection_y_coordinate_bnds$block_size
# $arrays$projection_y_coordinate_bnds$block_size[[1]]
# [1] 10
#
# $arrays$projection_y_coordinate_bnds$block_size[[2]]
# [1] 2
#
#
# $arrays$projection_y_coordinate_bnds$nodata_value
# [1] "NaN"
#
#
# $arrays$rainfall
# $arrays$rainfall$datatype
# [1] "Float64"
#
# $arrays$rainfall$dimensions
# $arrays$rainfall$dimensions[[1]]
# [1] "/time"
#
# $arrays$rainfall$dimensions[[2]]
# [1] "/projection_y_coordinate"
#
# $arrays$rainfall$dimensions[[3]]
# [1] "/projection_x_coordinate"
#
#
# $arrays$rainfall$dimension_size
# $arrays$rainfall$dimension_size[[1]]
# [1] 48943
#
# $arrays$rainfall$dimension_size[[2]]
# [1] 1450
#
# $arrays$rainfall$dimension_size[[3]]
# [1] 900
#
#
# $arrays$rainfall$block_size
# $arrays$rainfall$block_size[[1]]
# [1] 49044
#
# $arrays$rainfall$block_size[[2]]
# [1] 10
#
# $arrays$rainfall$block_size[[3]]
# [1] 10
#
#
# $arrays$rainfall$attributes
# $arrays$rainfall$attributes$cell_methods
# [1] "time: sum"
#
# $arrays$rainfall$attributes$coordinates
# [1] "latitude longitude"
#
# $arrays$rainfall$attributes$description
# [1] "Total rainfall"
#
# $arrays$rainfall$attributes$grid_mapping
# [1] "transverse_mercator"
#
# $arrays$rainfall$attributes$label_units
# [1] "mm"
#
# $arrays$rainfall$attributes$level
# [1] "NA"
#
# $arrays$rainfall$attributes$long_name
# [1] "Total rainfall"
#
# $arrays$rainfall$attributes$plot_label
# [1] "Total rainfall (mm)"
#
# $arrays$rainfall$attributes$standard_name
# [1] "lwe_thickness_of_precipitation_amount"
#
#
# $arrays$rainfall$unit
# [1] "mm"
#
# $arrays$rainfall$nodata_value
# [1] 1e+20
#
#
# $arrays$time_bnds
# $arrays$time_bnds$datatype
# [1] "Int64"
#
# $arrays$time_bnds$dimensions
# $arrays$time_bnds$dimensions[[1]]
# [1] "/time"
#
# $arrays$time_bnds$dimensions[[2]]
# [1] "/bnds"
#
#
# $arrays$time_bnds$dimension_size
# $arrays$time_bnds$dimension_size[[1]]
# [1] 48943
#
# $arrays$time_bnds$dimension_size[[2]]
# [1] 2
#
#
# $arrays$time_bnds$block_size
# $arrays$time_bnds$block_size[[1]]
# [1] 49044
#
# $arrays$time_bnds$block_size[[2]]
# [1] 2
#
#
# $arrays$time_bnds$attributes
# $arrays$time_bnds$attributes$calendar
# [1] "standard"
#
#
# $arrays$time_bnds$unit
# [1] "hours since 1800-01-01 00:00:00"
#
#
# $arrays$transverse_mercator
# $arrays$transverse_mercator$datatype
# [1] "Int32"
#
# $arrays$transverse_mercator$attributes
# $arrays$transverse_mercator$attributes$false_easting
# [1] 400000
#
# $arrays$transverse_mercator$attributes$false_northing
# [1] -100000
#
# $arrays$transverse_mercator$attributes$grid_mapping_name
# [1] "transverse_mercator"
#
# $arrays$transverse_mercator$attributes$latitude_of_projection_origin
# [1] 49
#
# $arrays$transverse_mercator$attributes$longitude_of_central_meridian
# [1] -2
#
# $arrays$transverse_mercator$attributes$longitude_of_prime_meridian
# [1] 0
#
# $arrays$transverse_mercator$attributes$scale_factor_at_central_meridian
# [1] 0.9996013
#
# $arrays$transverse_mercator$attributes$semi_major_axis
# [1] 6377563
#
# $arrays$transverse_mercator$attributes$semi_minor_axis
# [1] 6356257

# %% [markdown]
# There's a lot of information here and it isn't very pretty, so let's focus on pulling out the bits of metadata that we need.

# %% [markdown]
# ---
# ## 2. Get more specific variable information
#
# ### Chunk sizes

# %% [markdown]
# First, let's check the chunking of the two datasets to confirm they are different. We will be looking at the ```rainfall``` variable.

# %% [markdown]
# We use the '$' syntax to navigate through the metadata tree. Here we are pulling out the ```dimensions``` (names), ```dimension_size```, and ```block_size``` information from the ```rainfall``` ```array```. The ```block_size``` represents the chunk sizes of each dimension.

# %%
info_json_spacechunk$arrays$rainfall$dimensions
info_json_spacechunk$arrays$rainfall$dimension_size
info_json_spacechunk$arrays$rainfall$block_size
# Out:
# [[1]]
# [1] "/time"
#
# [[2]]
# [1] "/projection_y_coordinate"
#
# [[3]]
# [1] "/projection_x_coordinate"
# [[1]]
# [1] 48943
#
# [[2]]
# [1] 1450
#
# [[3]]
# [1] 900
# [[1]]
# [1] 49044
#
# [[2]]
# [1] 10
#
# [[3]]
# [1] 10

# %% [markdown]
# By comparing the space-chunked version above to the time-chunked version below, we can see that (only) the chunk sizes (```block_size```s) are different.
#
# In the space-chunked version above we can see that the ```x``` and ```y``` dimensions are chunked into blocks of 10.
#
# In the time-chunked version below we can that the ```time``` dimension is chunked into blocks of 7.
#
# In each case, the other dimensions have a chunk size equal to or exceeding their dimension size - i.e. they are not split up or chunked.

# %%
info_json_timechunk$arrays$rainfall$dimensions
info_json_timechunk$arrays$rainfall$dimension_size
info_json_timechunk$arrays$rainfall$block_size
# Out:
# [[1]]
# [1] "/time"
#
# [[2]]
# [1] "/projection_y_coordinate"
#
# [[3]]
# [1] "/projection_x_coordinate"
# [[1]]
# [1] 48943
#
# [[2]]
# [1] 1450
#
# [[3]]
# [1] 900
# [[1]]
# [1] 7
#
# [[2]]
# [1] 1450
#
# [[3]]
# [1] 900

# %% [markdown]
# ### Attributes
#
# Let's now look at some of the other metadata about the ```rainfall``` variable in the dataset. The metadata will be the same between the version of the dataset, so we can use either here.

# %%
# Navigate to the variable's attributes
var_attrs <- info_json_spacechunk$arrays$rainfall$attributes
print(var_attrs)
# Out:
# $cell_methods
# [1] "time: sum"
#
# $coordinates
# [1] "latitude longitude"
#
# $description
# [1] "Total rainfall"
#
# $grid_mapping
# [1] "transverse_mercator"
#
# $label_units
# [1] "mm"
#
# $level
# [1] "NA"
#
# $long_name
# [1] "Total rainfall"
#
# $plot_label
# [1] "Total rainfall (mm)"
#
# $standard_name
# [1] "lwe_thickness_of_precipitation_amount"

# %% [markdown]
# ### Variable dimensions

# %% [markdown]
# We can also use `stars`' built-in multi-dimension array reader to view some of the information. It can't access the full metadata like ```gdal``` can above, but can provide information on the dimensions of variables from the dataset.

# %%
dataset_spacechunk <- read_mdim(gdal_url_spacechunk, variable = "rainfall", proxy=TRUE)

# ── Show dataset dimensions and basic metadata ───────────────────────────────
dims_spacechunk <- st_dimensions(dataset_spacechunk)
print(dims_spacechunk)
# Out:
#                         from    to     offset  delta refsys x/y
# projection_x_coordinate    1   900     -2e+05   1000     NA [x]
# projection_y_coordinate    1  1450     -2e+05   1000     NA [y]
# time                       1 48943 1891-01-01 1 days   Date

# %% [markdown]
# ### Read coordinate arrays
#
# We can also `stars`' dimension reader to see the coordinate values:

# %%
# ── Extract coordinate vectors from st_dimensions() ─────────────────────────
# stars stores coordinate values directly in the dimension metadata;
# no need to read them as separate arrays

dims <- st_dimensions(dataset_spacechunk)

xs      <- st_get_dimension_values(dataset_spacechunk, "projection_x_coordinate")
ys    <- st_get_dimension_values(dataset_spacechunk, "projection_y_coordinate")
datetimes <- st_get_dimension_values(dataset_spacechunk, "time")

# stars decodes CF time automatically — datetimes is already a POSIXct vector
cat(sprintf("x   : %d values, %.3f to %.3f\n",
  length(xs), min(xs), max(xs)))
cat(sprintf("y   : %d values, %.3f to %.3f\n",
  length(ys), min(ys), max(ys)))
cat(sprintf("Time: %d steps, from %s to %s\n",
  length(datetimes), format(min(datetimes)), format(max(datetimes))))
# Out:
# x   : 900 values, -199500.000 to 699500.000
# y   : 1450 values, -199500.000 to 1249500.000
# Time: 48943 steps, from 1891-01-01 to 2024-12-31

# %% [markdown]
# Now that we've explored the metadata, we can get going with a couple of simple examples, using the appropriate chunking for each.

# %% [markdown]
# ---
# ## 3. Time series at a single grid point
#
# We will get better performance on this example if we use the version of the dataset that is chunked in space, and not in time. This store uses 10km × 10km chunks, therefore a single point time series will download only one chunk, the chunk that contains the gridpoint we've requested.
#
# `stars` uses GDAL's `/vsicurl/` HTTP range request support under the hood, which ensures that only the chunks covering the requested subset are fetched from the cloud store.

# %%
# ── Choose a target location ──────────────────────────────────────────────────
# E.g. Edinburgh, Scotland (British National Grid)
target_x <- 325000
target_y <- 673000

# Find the nearest grid cell coordinate values
nearest_x <- xs[which.min(abs(xs - target_x))]
nearest_y <- ys[which.min(abs(ys - target_y))]

cat(sprintf("Target location  : x=%.0f, y=%.0f\n", target_x, target_y))
cat(sprintf("Nearest grid cell: x=%.0f, y=%.0f\n", nearest_x, nearest_y))
# Out:
# Target location  : x=325000, y=673000
# Nearest grid cell: x=324500, y=672500

# %% [markdown]
# Read a specific time period of the dataset for this location:

# %%
# ── Read the time series for this grid cell using coordinate-based selection ──

# Specify the time range of interest
time_start <- as.POSIXct("2015-01-01", tz = "UTC")
time_end   <- as.POSIXct("2015-12-31 23:00:00", tz = "UTC")

# Find the time indices covering the requested range
t_idx <- which(datetimes >= time_start & datetimes <= time_end)
t_offset <- min(t_idx) - 1L
t_count  <- length(t_idx)

# Find the nearest grid cell indices
x_idx <- which.min(abs(xs - target_x))
y_idx <- which.min(abs(ys - target_y))

cat(sprintf("Reading %d time steps (%s to %s) for grid cell [x=%.0f, y=%.0f]...\n",
  t_count, format(time_start, "%Y-%m-%d"), format(time_end, "%Y-%m-%d"),
  xs[x_idx], ys[y_idx]))

# Read only the needed subset
ts_stars <- read_mdim(
  gdal_url_spacechunk, # <--- note using the space-chunked dataset version
  variable = "rainfall",
  offset   = c(x_idx - 1L, y_idx - 1L, t_offset),
  count    = c(1L, 1L, t_count)
)

# Build tidy data frame
ts_df <- data.frame(
  datetime = datetimes[t_idx],
  value    = as.numeric(ts_stars[[1]])
)
tail(ts_df)
# Out:
# Reading 365 time steps (2015-01-01 to 2015-12-31) for grid cell [x=324500, y=672500]...
#     datetime   value
# 360 2015-12-26 17.76667645
# 361 2015-12-27  0.01766670
# 362 2015-12-28  0.00362359
# 363 2015-12-29  4.44980178
# 364 2015-12-30  5.23590171
# 365 2015-12-31  0.82384429

# %% [markdown]
# Plot it

# %%
# ── Plot: full time series ────────────────────────────────────────────────────

# Extract out needed metadata
var_long  <- "rainfall"
var_units <- info_json_spacechunk$arrays$rainfall$unit
y_label     <- if (nchar(var_units) > 0) paste0(var_long, "\n(", var_units, ")") else var_long
subtitle_ts <- sprintf("Grid cell: x=%.0f, y=%.0f (BNG EPSG:27700)", nearest_x, nearest_y)

# construct plot
p_ts <- ggplot(ts_df, aes(x = datetime, y = value)) + # data to plot
  geom_line(colour = "blue", linewidth = 0.5) + # line properties
  scale_x_datetime(labels = scales::date_format("%b %Y")) + # x axis label formatting
  scale_y_continuous(labels = scales::comma) + # y axis label formatting
  labs( # labels
    title    = paste("HadUK-Grid Rainfall", var_long),
    subtitle = subtitle_ts,
    x        = NULL,
    y        = y_label,
    caption  = "Source: FDRI / CEDA· https://dx.doi.org/10.5285/f02cc6ddd92f45b18b9ab6ab544df7d9"
  ) +
  theme_minimal(base_size = 12)

print(p_ts)
# Out:
# plot without title

# %% [markdown]
# ---
# ## 4. Spatial map at a single time step
#
# We will get better performance on this example if we use the version of the dataset that is chunked in time, and not in space. This store uses daily (24 hourly time step) chunks, therefore a spatial extraction at only one time step will download only one chunk, the chunk that contains the timestep we've requested.
#
# As before, `stars` uses GDAL's `/vsicurl/` HTTP range request support under the hood, which ensures that only the chunks covering the requested subset are fetched from the cloud store. You are however likely to run into memory issues on Binder which is limited to 2GB of RAM. Try extracting out only a portion of the whole 2D slice if you encounter issues with memory.

# %%
# ── Read the full spatial grid for a specific time step ───────────────────────

# Specify the time of interest
target_time <- as.POSIXct("2000-01-01", tz = "UTC")

# Find the nearest time step
t_idx  <- which.min(abs(as.POSIXct(datetimes) - target_time))
slice_time <- format(datetimes[t_idx], "%Y-%m-%d UTC")
cat(sprintf("Reading spatial slice for %s (time index %d)\n", slice_time, t_idx))

# Read the full x/y grid for that time step
slice_stars <- read_mdim(
  gdal_url_timechunk, # <--- note using the time-chunked dataset version
  variable = "rainfall",
  offset   = c(0L, 0L, t_idx - 1L),
  count    = c(length(xs), length(ys), 1L)
)

cat(sprintf("Grid: %d x × %d y\n", length(xs), length(ys)))
cat(sprintf("Value range: %.3f to %.3f %s\n",
  min(slice_stars[[1]], na.rm = TRUE),
  max(slice_stars[[1]], na.rm = TRUE),
  var_units))
# Out:
# Reading spatial slice for 2000-01-01 UTC (time index 39812)
# Grid: 900 x × 1450 y
# Value range: 0.000 to 82.283 mm

# %% [markdown]
# To plot this nicely, several plotting libraries need to be installed. This can take upwards of 15 minutes. There are slight variations in how this needs to be done for different platforms. Follow the instructions and run the cells **only** for the platform you are currently running the notebook on.

# %% [markdown]
# #### Google Colab

# %%
# Set up r2u for installing terra (uses precompiled binaries to bypass gdal problems)
download.file(
  "https://github.com/eddelbuettel/r2u/raw/master/inst/scripts/add_cranapt_focal.sh",
  "add_cranapt_focal.sh"
)
Sys.chmod("add_cranapt_focal.sh", "0755")
system("./add_cranapt_focal.sh")

# %% [markdown]
# #### JASMIN Notebook Service

# %% [markdown]
# JASMIN sometimes fails to find the proj directory, which contains the files needed for spatial plotting, meaning you have to set it manually. If you have followed the instructions for the JASMIN Notebook Service on the README, the proj directory should be installed in the directory written out in the commands below. You will need to replace "USERNAME" with your JASMIN username and "ENVNAME" with the name of the environment you created with conda when cloning the jasR environment (this is fdriR if you've followed the instructions word for word).

# %%
# only needs to be run on the JASMIN Notebook Service.

proj_dir <- "/gws/ssde/j25b/fdri/envs/fdricombo/share/proj"
Sys.setenv(PROJ_DATA = file.path(proj_dir))
Sys.setenv(PROJ_LIB = file.path(proj_dir))

# %% [markdown]
# To check you have set this correctly, the following command should pass (i.e. not produce an error):

# %%
stopifnot(file.exists(file.path(Sys.getenv("PROJ_DATA"), "proj.db")))

# %% [markdown]
# If it produces an error, it is likely proj_dir and thus PROJ_DATA is not correct. You can see what PROJ_DATA is with the below command. Double check proj_dir is set correctly.

# %%
Sys.getenv("PROJ_DATA")

# %% [markdown]
# #### Binder
#
# All packages are already set up and installed on Binder, no further configuration is required.

# %% [markdown]
# ### All platforms - Install libraries

# %% [markdown]
# Packages will only be installed if they are not already.

# %%
pkgs <- c("rnaturalearth", "rnaturalearthdata")
new  <- pkgs[!pkgs %in% installed.packages()[, "Package"]]
if (length(new) > 0) install.packages(new, repos = "https://cloud.r-project.org", verbose = TRUE)

# %%
library('ggplot2')
library('rnaturalearth')
library('rnaturalearthdata')

# %% [markdown]
# ### Plot

# %%
# ── Plot the spatial slice using stars + ggplot2 ─────────────────────────────

# Drop the singleton time dimension so we have a clean 2D raster
slice_2d <- adrop(slice_stars)

# Set the EPSG code (the grid projection) For an OSGB grid it is 27700
st_crs(slice_2d) <- "EPSG:27700"

# Get UK coastline for overlay, transformed to the CRS
gb <- ne_countries(country = "United Kingdom",
                   scale = "medium", returnclass = "sf") |>
  st_transform(st_crs(slice_2d))

# geom_stars() renders a stars object directly in ggplot2
p_map <- ggplot() +
  geom_stars(data = slice_2d) + # render the data
  geom_sf(data = gb, fill = NA) + # render the coastlines
  scale_fill_distiller( # customise how the data is displayed
    palette   = "YlGnBu",
    direction = 1,
    name      = var_units,
    na.value  = NA,
    labels    = scales::comma
  ) +
  coord_sf(expand = FALSE) + # customise how the plot overall is displayed
  labs(
    title    = paste("HadUK-Grid Rainfall", var_long),
    subtitle = slice_time,
    x = "Lon", y = "Lat",
    caption  = "Source: FDRI / CEDA· https://dx.doi.org/10.5285/f02cc6ddd92f45b18b9ab6ab544df7d9"
  ) +
  theme_minimal(base_size = 12)

print(p_map)
# Out:
# Warning message:
# “Removed 1059923 rows containing missing values or values outside the scale
# range (`geom_raster()`).”
# plot without title

# %% [markdown]
# ---
# ## Appendix
#
# ### Troubleshooting
#
# | Symptom | Fix |
# |---------|-----|
# | `read_mdim()` errors with "no such file" | Check the GDAL Zarr URL format: must be `ZARR:"/vsicurl/https://..."` |
# | Variable name not found | Run `gdal_utils("mdiminfo", gdal_url)` to see available variables; update the `variable =` argument |
# | Map looks blank or all NA | Check `offset` and `count` values match the actual array dimension order |
# | Time values look wrong | `stars` decodes CF time automatically; check `st_get_dimension_values(dataset, "time")` |
# | Data is slow to extract | Expected over HTTP for large slices; GDAL fetches only the needed chunks but chunk size affects speed |
# | Runtime crashes due to lack of RAM | Reading large slices can exhaust memory on Binder (2GB limit). Try a smaller subset or use a different platform |

# %% [markdown]
# ---
#
# **Data citation:** HadUK-Grid, Met Office. https://dx.doi.org/10.5285/f02cc6ddd92f45b18b9ab6ab544df7d9
